# %% [markdown]
# # To install yfinance before you use it.
# #  pip install yfinance

# %% [markdown]
# Top e-commerce companies
# -- Amazon. Though it started in 1994 as an e-commerce marketplace for books, Amazon has evolved into an online shopping staple. ...
# Wal-Mart Stores Inc. ...
# Alibaba Group Holding Ltd. ...
# Facebook. ...
# Microsoft. ...
# Apple Inc. ...
# eBay Inc. ...
# Liberty Interactive Corporation.

# %%
import yfinance as yf

# %% [markdown]
# Amazon

# %%
amzn = yf.Ticker("AMZN")
print(amzn)
# Out:
# yfinance.Ticker object <AMZN>

# %%
# get stock info
amzn.info
# Out:
# {'zip': '98109-5210',
#  'sector': 'Consumer Cyclical',
#  'fullTimeEmployees': 1468000,
# ...

# %%
# get historical market data, here max is 5 years.
amzn.history(period="max")
# Out:
#                    Open         High          Low        Close    Volume  \
# Date
# 1997-05-15     2.437500     2.500000     1.927083     1.958333  72156000
# 1997-05-16     1.968750     1.979167     1.708333     1.729167  14700000
# 1997-05-19     1.760417     1.770833     1.625000     1.708333   6106800
# 1997-05-20     1.729167     1.750000     1.635417     1.635417   5467200
# 1997-05-21     1.635417     1.645833     1.375000     1.427083  18853200
# ...                 ...          ...          ...          ...       ...
# 2022-01-12  3331.500000  3337.560059  3288.340088  3304.139893   2501500
# 2022-01-13  3305.010010  3324.429932  3221.820068  3224.280029   2609400
# 2022-01-14  3203.000000  3245.000000  3196.010010  3242.760010   2295800
# 2022-01-18  3182.100098  3194.689941  3153.290039  3178.350098   3364600
# 2022-01-19  3175.239990  3185.000000  3136.000000  3148.330078   1102330
#
#             Dividends  Stock Splits
# Date
# 1997-05-15          0           0.0
# ...

# %% [markdown]
# Alibaba

# %%
baba = yf.Ticker("BABA")
print(baba)
# Out:
# yfinance.Ticker object <BABA>

# %%
# get stock info
baba.info
# Out:
# {'zip': '311121',
#  'sector': 'Consumer Cyclical',
#  'fullTimeEmployees': 258578,
# ...

# %%
# get historical market data, here max is 5 years.
baba.history(period="max")
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2014-09-19   92.699997   99.699997   89.949997   93.889999  271879400
# 2014-09-22   92.699997   92.949997   89.500000   89.889999   66657800
# 2014-09-23   88.940002   90.480003   86.620003   87.169998   39009800
# 2014-09-24   88.470001   90.570000   87.220001   90.570000   32088000
# 2014-09-25   91.089996   91.500000   88.500000   88.919998   28598000
# ...                ...         ...         ...         ...        ...
# 2022-01-12  136.020004  138.699997  135.585007  137.410004   25961100
# 2022-01-13  135.199997  135.919998  131.300003  131.369995   19887700
# 2022-01-14  132.809998  134.360001  129.350006  131.570007   18603400
# 2022-01-18  126.269997  132.130005  124.820000  128.600006   26122200
# 2022-01-19  128.100006  130.860001  127.129997  129.128204    8180505
#
#             Dividends  Stock Splits
# Date
# 2014-09-19          0             0
# 2014-09-22          0             0
# ...

# %% [markdown]
# Shopify

# %%
shop = yf.Ticker("SHOP")
print(shop)
# Out:
# yfinance.Ticker object <SHOP>

# %%
# get stock info
shop.info
# Out:
# {'zip': 'K2P 2L8',
#  'sector': 'Technology',
#  'fullTimeEmployees': 7000,
# ...

# %%
# get historical market data, here max is 5 years.
shop.history(period="max")
# Out:
#                    Open         High          Low        Close    Volume  \
# Date
# 2015-05-20    17.000000    17.000000    17.000000    17.000000         0
# 2015-05-21    28.000000    28.740000    24.110001    25.680000  12303900
# 2015-05-22    26.070000    31.100000    26.000000    28.309999   2841200
# 2015-05-26    29.799999    30.340000    29.080000    29.650000    820200
# 2015-05-27    30.670000    30.809999    27.000000    27.500000    797600
# ...                 ...          ...          ...          ...       ...
# 2022-01-12  1185.160034  1191.199951  1157.000000  1168.760010   1132900
# 2022-01-13  1170.000000  1178.050049  1061.500000  1064.359985   2280100
# 2022-01-14  1053.000000  1111.979980  1048.600952  1102.910034   2216500
# 2022-01-18  1087.209961  1088.339966  1029.060059  1054.660034   2187100
# 2022-01-19  1068.209961  1122.349976  1065.819946  1076.489990   1155304
#
#             Dividends  Stock Splits
# Date
# 2015-05-20          0             0
# ...
